# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("/content/creditcard.csv.zip")
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# ...

# %%
pd.options.display.max_columns = None

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %%
fraud=data[data['Class']==1]
print(fraud)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 284807
# Number of Columns 31

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
data['Amount']=sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
data = data.drop(['Time'],axis=1)

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
data.shape
# Out:
# (284807, 30)

# %%
data.duplicated().any()
# Out:
# True

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (275663, 30)

# %%
print("no of duplicate values removed = ",284807-275663)
# Out:
# no of duplicate values removed =  9144

# %%
import matplotlib.pyplot as plt

# %%
fraud=data[data['Class']==1]
normal=data[data['Class']==0]

count_classes=pd.Series(data['Class']).value_counts(sort=True)
count_classes.plot(kind='bar',rot=0)

plt.title("Transaction Class Distribution")
Lables=["Normal","Fraud"]

plt.xticks(range(2),Lables)

plt.xlabel("CLASS")
plt.ylabel("FREQUENCY")
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %% [markdown]
# Preprocess and Splitting The Dataset Into The Training Set And Test Set

# %%
from sklearn.model_selection import train_test_split
X = data.drop('Class',axis=1)
y = data['Class']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,
                                                 random_state=42)

# %% [markdown]
# # Handling Imbalanced Dataset

# %% [markdown]
# Undersampling

# %%
normal = data[data['Class']==0]
fraud = data[data['Class']==1]

# %%
normal.shape
# Out:
# (275190, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample=normal.sample(n=473)

# %%
normal_sample.shape
# Out:
# (473, 30)

# %%
new_data = pd.concat([normal_sample,fraud],ignore_index=True)

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    473
# 1    473
# Name: count, dtype: int64

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  1.200535  0.026079  0.899597  0.966337 -0.304354  0.408092 -0.468112
# 1  2.191514 -0.554837 -1.402956 -0.898766 -0.378406 -1.449640 -0.029428
# 2 -0.584534  0.516797  2.690273  1.666086 -0.497783  0.712059  0.238978
# 3  1.766044 -1.119247 -0.901301  0.611995 -0.722519 -0.021470 -0.495643
# 4 -0.608037  0.277482  2.333740  0.713876 -0.686327  0.424502  0.158410
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.002263  2.070849 -0.774613  0.114506 -1.174605  3.009026  0.668576
# 1 -0.509788 -0.858885  0.815396 -0.283117  0.050167  1.202661 -0.041740
# 2  0.218306  0.836184 -0.230991 -0.925410  0.171602 -1.182761 -0.824100
# 3  0.011689 -0.479086  1.129786  0.070520  0.230204 -0.436864  0.340934
# 4  0.277078  0.005665 -0.574444 -0.383596  0.063757  0.435809 -0.294166
#
#         V15       V16       V17       V18       V19       V20       V21  \
# ...

# %%
count_classes=pd.Series(new_data['Class']).value_counts(sort=True)
count_classes.plot(kind='bar',rot=0)

plt.title("Transaction Class Distribution")
Lables=["Normal","Fraud"]

plt.xticks(range(2),Lables)

plt.xlabel("CLASS")
plt.ylabel("FREQUENCY")
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %%
X = new_data.drop('Class',axis=1)
y = new_data['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,
                                                 random_state=42)

# %% [markdown]
# # Model Building

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = log.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred1)
# Out:
# 0.9315789473684211

# %%
from sklearn.metrics import precision_score,recall_score,f1_score

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.9494949494949495

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9215686274509803

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9353233830845771

# %% [markdown]
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(X_test)
accuracy_score(y_test,y_pred2)
# Out:
# 0.8789473684210526

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.8910891089108911

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.8823529411764706

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.8866995073891626

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(X_test)
accuracy_score(y_test,y_pred3)
# Out:
# 0.9421052631578948

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9789473684210527

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.9117647058823529

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9441624365482234

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
rf = KNeighborsClassifier()
rf.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred4 = rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred4)
# Out:
# 0.9210526315789473

# %%
precision_score(y_test,y_pred4)
# Out:
# 0.9484536082474226

# %%
recall_score(y_test,y_pred4)
# Out:
# 0.9019607843137255

# %%
f1_score(y_test,y_pred4)
# Out:
# 0.9246231155778895

# %% [markdown]
# XGBoost classifier

# %%
from xgboost import XGBClassifier

# %%
rf = XGBClassifier()
rf.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred5 = rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.9421052631578948

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9789473684210527

# %%
recall_score(y_test,y_pred3)
# Out:
# 0.9117647058823529

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9441624365482234

# %%
final_data = pd.DataFrame({'Models':['LR','DT','RF','KNN','XGB'],
              "ACC":[accuracy_score(y_test,y_pred1)*100,
                     accuracy_score(y_test,y_pred2)*100,
                     accuracy_score(y_test,y_pred3)*100
                     ,accuracy_score(y_test,y_pred4)*100
                     ,accuracy_score(y_test,y_pred5)*100],
                    })

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  93.157895
# 1     DT  87.894737
# 2     RF  94.210526
# 3    KNN  92.105263
# 4    XGB  94.210526

# %%
count_classes=pd.Series(final_data['ACC'])
count_classes.plot(kind='bar',rot=0)

plt.title("finding best model")
Lables=["LR","DT","RF","KNN","XGB"]

plt.xticks(range(5),Lables)

plt.xlabel("MODELS")
plt.ylabel("ACC")
# Out:
# Text(0, 0.5, 'ACC')

# %% [markdown]
# Oversampling

# %%
X = data.drop('Class',axis=1)
y = data['Class']

# %%
X.shape
# Out:
# (275663, 29)

# %%
y.shape
# Out:
# (275663,)

# %%
from imblearn.over_sampling import SMOTE

# %%
X_res,y_res = SMOTE().fit_resample(X,y)

# %%
y_res.value_counts()
# Out:
# Class
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_res,y_res,test_size=0.20,
                                                 random_state=42)

# %% [markdown]
# # Model Building

# %% [markdown]
# Logistic Regression

# %%
log = LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = log.predict(X_test)

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.9452650895744759

# %%
precision_score(y_test,y_pred1)
# Out:
# 0.9731808169416857

# %%
recall_score(y_test,y_pred1)
# Out:
# 0.9156955075177717

# %%
f1_score(y_test,y_pred1)
# Out:
# 0.9435634197289171

# %% [markdown]
#  Decision Tree Classifier

# %%
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)
# Out:
# 0.9979559577019513

# %%
precision_score(y_test,y_pred2)
# Out:
# 0.9972043713466217

# %%
recall_score(y_test,y_pred2)
# Out:
# 0.9987091613184735

# %%
f1_score(y_test,y_pred2)
# Out:
# 0.9979561990752936

# %% [markdown]
# Random Forest Classifier

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.999918238308078

# %%
precision_score(y_test,y_pred3)
# Out:
# 0.9998363993310551

# %%
recall_score(y_test,y_pred3)
# Out:
# 1.0

# %%
f1_score(y_test,y_pred3)
# Out:
# 0.9999181929736854

# %% [markdown]
# KNN classifer

# %%
rf = KNeighborsClassifier()
rf.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred4 = rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred4)
# Out:
# 0.999046113594244

# %%
precision_score(y_test,y_pred4)
# Out:
# 0.998094650504464

# %%
recall_score(y_test,y_pred4)
# Out:
# 1.0

# %%
f1_score(y_test,y_pred4)
# Out:
# 0.9990464167975952

# %% [markdown]
# XGBoost classifier

# %%
rf = XGBClassifier()
rf.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred5 = rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred5)
# Out:
# 0.9997365456593627

# %%
precision_score(y_test,y_pred5)
# Out:
# 0.9994730338712022

# %%
recall_score(y_test,y_pred5)
# Out:
# 1.0

# %%
f1_score(y_test,y_pred5)
# Out:
# 0.9997364474939792

# %%
final_data = pd.DataFrame({'Models':['LR','DT','RF','KNN','XGB'],
              "ACC":[accuracy_score(y_test,y_pred1)*100,
                     accuracy_score(y_test,y_pred2)*100,
                     accuracy_score(y_test,y_pred3)*100
                     ,accuracy_score(y_test,y_pred4)*100
                     ,accuracy_score(y_test,y_pred5)*100],
                    })

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  94.526509
# 1     DT  99.795596
# 2     RF  99.991824
# 3    KNN  99.904611
# 4    XGB  99.973655

# %%
count_classes=pd.Series(final_data['ACC'])
count_classes.plot(kind='bar',rot=0)

plt.title("finding best model")
Lables=["LR","DT","RF","KNN","XGB"]

plt.xticks(range(5),Lables)

plt.xlabel("MODELS")
plt.ylabel("ACC")
# Out:
# Text(0, 0.5, 'ACC')

# %% [markdown]
# Save The Model

# %%
rf1 = RandomForestClassifier()
rf1.fit(X_res,y_res)
# Out:
# RandomForestClassifier()

# %%
import joblib

# %%
joblib.dump(rf1,"credit_card_model")
# Out:
# ['credit_card_model']

# %%
model=joblib.load("credit_card_model")

# %%
pred = model.predict([[-2.312227  ,1.951992 ,-1.609851  ,3.997906 ,-0.522188,
                       -1.426545,-2.537387,1.391657 ,-2.770089 ,-2.772272 ,
                       3.202033,  -2.899907 ,-0.595222,-4.289254  ,0.389724,
                       -1.140747,-2.830056, -0.016822,  0.416956,  0.126911,
                       0.517232, -0.035049, -0.465211,  0.320198 , 0.044519,
                       0.177840,  0.261145,-0.143276,0.044519 ]])

# %%
if pred == 0:
    print("Normal Transcation")
else:
    print("Fraudulent Transcation")
# Out:
# Fraudulent Transcation
